# %%
# !unzip smartphone+based+recognition+of+human+activities+and+postural+transitions.zip
# Out:
# /bin/bash: line 1: unzip: command not found

# %%
import zipfile
import os

with zipfile.ZipFile('UCI HAR Dataset.zip', 'r') as zip_ref:
    zip_ref.extractall('')

# %%
import numpy as np

# %%
def raw_data(folder):
    signals = []
    types = [
        'body_acc_x','body_acc_y','body_acc_z','total_acc_x','total_acc_y','total_acc_z',
        'body_gyro_x','body_gyro_y','body_gyro_z'
    ]
    for signal in types:
        path = f"UCI HAR Dataset/{folder}/Inertial Signals/{signal}_{folder}.txt"
        data = np.loadtxt(path)
        signals.append(data)
    X = np.dstack(signals) # to stack along the 3rd dim 
    y = (np.loadtxt(f"UCI HAR Dataset/{folder}/y_{folder}.txt"))-1 # for starting from 0 index
    return X,y

# %%
X_train, y_train = raw_data('train')
X_test, y_test = raw_data('test')

# %%
print(X_train.shape) 
print(X_test.shape)
# Out:
# (7352, 128, 9)
# (2947, 128, 9)

# %%
print(np.unique(y_test))
# Out:
# [0. 1. 2. 3. 4. 5.]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
# Out:
# 2025-03-01 17:43:03.865624: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-01 17:43:04.432207: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-01 17:43:04.703272: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-03-01 17:43:04.779729: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-01 17:43:05.251039: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
lstm_model = Sequential([
    LSTM(64, return_sequences=True, input_shape=(128, 9)),
    Dropout(0.3),
    LSTM(64),
    Dropout(0.3),
    Dense(6, activation='softmax')  #  there are 6 activity classes
])
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1740831195.418224   13375 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1740831195.609192   13375 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1740831195.609415   13375 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1740831195.619400   13375 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1740831195.619546   13375 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1740831195.619594   13375 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1740831196.611197   13375 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1740831196.611471   13375 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-03-01 17:43:16.611503: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# I0000 00:00:1740831196.611606   13375 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-03-01 17:43:16.612962: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5563 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# /home/ananya/miniconda3/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
lstm_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history = lstm_model.fit(X_train, y_train, epochs=15, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/15
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 16s 67ms/step - accuracy: 0.4793 - loss: 1.2347 - val_accuracy: 0.6071 - val_loss: 0.9069
# Epoch 2/15
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 11s 59ms/step - accuracy: 0.7685 - loss: 0.5869 - val_accuracy: 0.8083 - val_loss: 0.5674
# Epoch 3/15
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 11s 61ms/step - accuracy: 0.8724 - loss: 0.3933 - val_accuracy: 0.8525 - val_loss: 0.4869
# Epoch 4/15
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 11s 58ms/step - accuracy: 0.9113 - loss: 0.2538 - val_accuracy: 0.8906 - val_loss: 0.3535
# Epoch 5/15
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 11s 58ms/step - accuracy: 0.9438 - loss: 0.1722 - val_accuracy: 0.8831 - val_loss: 0.3534
# Epoch 6/15
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 11s 58ms/step - accuracy: 0.9400 - loss: 0.1696 - val_accuracy: 0.9035 - val_loss: 0.3638
# Epoch 7/15
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 11s 61ms/step - accuracy: 0.9448 - loss: 0.1493 - val_accuracy: 0.9028 - val_loss: 0.3801
# Epoch 8/15
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 11s 59ms/step - accuracy: 0.9505 - loss: 0.1333 - val_accuracy: 0.8946 - val_loss: 0.4069
# Epoch 9/15
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 12s 64ms/step - accuracy: 0.9519 - loss: 0.1173 - val_accuracy: 0.8736 - val_loss: 0.5410
# Epoch 10/15
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 12s 64ms/step - accuracy: 0.9357 - loss: 0.1848 - val_accuracy: 0.8939 - val_loss: 0.4460
# Epoch 11/15
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 12s 66ms/step - accuracy: 0.9495 - loss: 0.1342 - val_accuracy: 0.9082 - val_loss: 0.4519
# Epoch 12/15
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 11s 61ms/step - accuracy: 0.9560 - loss: 0.1146 - val_accuracy: 0.8987 - val_loss: 0.4863
# Epoch 13/15
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - accuracy: 0.9460 - loss: 0.1365 - val_accuracy: 0.8885 - val_loss: 0.4592
# Epoch 14/15
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 12s 63ms/step - accuracy: 0.9348 - loss: 0.1611 - val_accuracy: 0.8906 - val_loss: 0.4633
# Epoch 15/15
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 12s 64ms/step - accuracy: 0.9475 - loss: 0.1646 - val_accuracy: 0.8885 - val_loss: 0.4884

# %%
lstm_accuracy = lstm_model.evaluate(X_test, y_test)[1]


print(f"LSTM Test Accuracy: {lstm_accuracy:.4f}")
# Out:
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.8816 - loss: 0.4694
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8830 - loss: 0.6417
# LSTM Test Accuracy: 0.9155
# 1D CNN Test Accuracy: 0.9223

# %%
print("Train shape:", X_train.shape)  # Should be (7352, 128, 9)
print("Test shape:", X_test.shape)    # Should be (2947, 128, 9)
# Out:
# Train shape: (7352, 128, 9)
# Test shape: (2947, 128, 9)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout

cnn_model = Sequential([
    Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(128, 9)),
    MaxPooling1D(pool_size=2),
    Conv1D(filters=128, kernel_size=3, activation='relu'),
    MaxPooling1D(pool_size=2),
    Flatten(),
    Dense(64, activation='relu'),
    Dropout(0.3),
    Dense(6, activation='softmax')  # 6 classes
])

cnn_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

history_cnn = cnn_model.fit(X_train, y_train, epochs=15, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/15
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - accuracy: 0.6677 - loss: 0.8455 - val_accuracy: 0.8668 - val_loss: 0.4482
# Epoch 2/15
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9218 - loss: 0.2109 - val_accuracy: 0.9123 - val_loss: 0.4027
# Epoch 3/15
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9421 - loss: 0.1307 - val_accuracy: 0.9123 - val_loss: 0.4357
# Epoch 4/15
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9478 - loss: 0.1296 - val_accuracy: 0.9096 - val_loss: 0.4274
# Epoch 5/15
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9530 - loss: 0.1041 - val_accuracy: 0.9109 - val_loss: 0.4910
# Epoch 6/15
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9632 - loss: 0.0845 - val_accuracy: 0.8878 - val_loss: 0.5328
# Epoch 7/15
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9561 - loss: 0.0945 - val_accuracy: 0.9123 - val_loss: 0.5555
# Epoch 8/15
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9592 - loss: 0.0879 - val_accuracy: 0.9157 - val_loss: 0.5810
# Epoch 9/15
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9627 - loss: 0.0789 - val_accuracy: 0.9123 - val_loss: 0.7194
# Epoch 10/15
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9622 - loss: 0.0814 - val_accuracy: 0.9150 - val_loss: 0.5633
# Epoch 11/15
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9632 - loss: 0.0723 - val_accuracy: 0.9007 - val_loss: 0.7665
# Epoch 12/15
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9653 - loss: 0.0741 - val_accuracy: 0.8742 - val_loss: 0.6805
# Epoch 13/15
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9604 - loss: 0.0788 - val_accuracy: 0.8967 - val_loss: 0.7027
# Epoch 14/15
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9671 - loss: 0.0609 - val_accuracy: 0.9041 - val_loss: 0.7694
# Epoch 15/15
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9731 - loss: 0.0620 - val_accuracy: 0.9137 - val_loss: 0.8371
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8722 - loss: 0.7062
# 1D CNN Test Accuracy: 0.9223

# %%
lstm_accuracy = cnn_model.evaluate(X_test, y_test)[1]
print(f"1D CNN Test Accuracy: {cnn_accuracy:.4f}")
# Out:
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8722 - loss: 0.7062
# 1D CNN Test Accuracy: 0.9223

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Get CNN Predictions
cnn_predictions = np.argmax(cnn_model.predict(X_test), axis=1)

# Get LSTM Predictions
lstm_predictions = np.argmax(lstm_model.predict(X_test), axis=1)

# Function to plot confusion matrix
def plot_confusion_matrix(y_true, y_pred, title):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=range(6), yticklabels=range(6))
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title(f"Confusion Matrix - {title}")
    plt.show()

# Plot for CNN
plot_confusion_matrix(y_test, cnn_predictions, "CNN")

# Plot for LSTM
plot_confusion_matrix(y_test, lstm_predictions, "LSTM")
# Out:
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step

# %%
plt.figure(figsize=(10, 5))
for i in range(3):  # Plot the first 3 signals
    plt.plot(X_train[0, :, i], label=f"Sensor {i+1}")

plt.title("Sample Sensor Readings")
plt.xlabel("Time Steps")
plt.ylabel("Sensor Value")
plt.legend()
plt.show()

# %%
import tsfel
import pandas as pd

# %%
cfg = tsfel.get_features_by_domain()

# %%
import pandas as pd
import numpy as np
X_train, y_train = raw_data('train')
X_test, y_test = raw_data('test')

# %%
import tsfel
import pandas as pd
import numpy as np

def time_series_features(X, sampling_rate=50):
    """
    Extracts TSFEL features from windowed time series data.
    
    Parameters:
        X: np.ndarray of shape (num_windows, window_size, num_channels)
            Windowed time series data.
        sampling_rate: int
            Sampling frequency of the data (Hz), e.g., 50Hz for HAR dataset.
            
    Returns:
        np.ndarray: Extracted features of shape (num_windows, num_features)
    """
    cfg = tsfel.get_features_by_domain()

    # Set sampling frequency in config (for frequency domain features)
    for domain in cfg.keys():
        for feature in cfg[domain]:
            if "Sampling frequency" in cfg[domain][feature]:
                cfg[domain][feature]["Sampling frequency"] = sampling_rate


    extracted_features = []

    # Iterate through each window
    for window in X:
        feature_vector = []

        
        for i in range(window.shape[1]):
            df = pd.DataFrame(window[:, i])

            # Extract features using TSFEL
            features = tsfel.time_series_features_extractor(cfg, df, verbose=0,fs=sampling_rate)
            
            # Flatten the features and append
            feature_vector.extend(features.values.flatten())

        extracted_features.append(feature_vector)

    return np.array(extracted_features)

# %%
X_train_features = time_series_features(X_train, sampling_rate=50)
X_test_features = time_series_features(X_test, sampling_rate=50)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 X_train_features = time_series_features(X_train, sampling_rate=50)
#       2 X_test_features = time_series_features(X_test, sampling_rate=50)
#
# Cell In[27], line 38, in time_series_features(X, sampling_rate)
#      35 df = pd.DataFrame(window[:, i])
#      37 # Extract features using TSFEL
# ---> 38 features = tsfel.time_series_features_extractor(cfg, df, verbose=0,fs=sampling_rate)
#      40 # Flatten the features and append
#      41 feature_vector.extend(features.values.flatten())
#
# File ~/miniconda3/lib/python3.12/site-packages/tsfel/feature_extraction/calc_features.py:377, in time_series_features_extractor(config, timeseries, fs, window_size, overlap, verbose, **kwargs)
#     372         raise SystemExit(
#     373             "n_jobs value is not valid. " "Choose an integer value or None for no multiprocessing.",
#     374         )
#     375 # single window
#     376 else:
# --> 377     features_final = calc_window_features(
#     378         config,
#     379         timeseries,
#     380         fs,
#     381         verbose=verbose,
#     382         features_path=features_path,
#     383         header_names=names,
#     384         single_window=True,
#     385     )
#     387 # Assuring the same feature extraction order
#     388 features_final = features_final.reindex(sorted(features_final.columns), axis=1)
#
# File ~/miniconda3/lib/python3.12/site-packages/tsfel/feature_extraction/calc_features.py:518, in calc_window_features(config, window, fs, verbose, single_window, **kwargs)
#     516 for ax in range(len(header_names)):
#     517     sig_ax = window if single_axis else window[:, ax]
# --> 518     eval_result_ax = locals()[func_total](sig_ax, **parameters_total)
#     520     # Function returns more than one element
#     521     if isinstance(eval_result_ax, tuple):
#
# File ~/miniconda3/lib/python3.12/site-packages/tsfel/feature_extraction/features.py:1074, in spectral_centroid(signal, fs)
#    1053 """Barycenter of the spectrum.
#    1054
#    1055 Description and formula in Article:
#    (...)
#    1071     Centroid
#    1072 """
#    1073 f, fmag = calc_fft(signal, fs)
# -> 1074 if not np.sum(fmag):
#    1075     return 0
#    1076 else:
#
# File ~/miniconda3/lib/python3.12/site-packages/numpy/core/fromnumeric.py:2313, in sum(a, axis, dtype, out, keepdims, initial, where)
#    2310         return out
#    2311     return res
# -> 2313 return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
#    2314                       initial=initial, where=where)
#
# File ~/miniconda3/lib/python3.12/site-packages/numpy/core/fromnumeric.py:71, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      60     except TypeError:
#      61         # A TypeError occurs if the object does have such a method in its
#      62         # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      66         # Call _wrapit from within the except clause to ensure a potential
#      67         # exception has a traceback chain.
#      68         return _wrapit(obj, method, *args, **kwds)
# ---> 71 def _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs):
#      72     passkwargs = {k: v for k, v in kwargs.items()
#      73                   if v is not np._NoValue}
#      75     if type(obj) is not mu.ndarray:
#
# KeyboardInterrupt:

# %%
print(X_train_features.shape)
print(X_test_features.shape)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score

# %%
rf = RandomForestClassifier()
rf.fit(X_train_features, y_train)
y_pred_rf = rf.predict(X_test_features)
print("random forest acc:", accuracy_score(y_test, y_pred_rf))

# %%
svm = SVC()
svm.fit(X_train_features, y_train)
y_pred_svm = svm.predict(X_test_features)
print("svm accuracy:", accuracy_score(y_test, y_pred_svm))

# %%
# Logistic Regression
lr = LogisticRegression(max_iter=1000)
lr.fit(X_train_features, y_train)
y_pred_lr = lr.predict(X_test_features)
print("Logistic Regression Accuracy:", accuracy_score(y_test, y_pred_lr))

# %%
X_train_authors = pd.read_csv('UCI HAR Dataset/train/X_train.txt', delim_whitespace=True, header=None).values
y_train = pd.read_csv('UCI HAR Dataset/train/y_train.txt', header=None).values.ravel()

X_test_authors = pd.read_csv('UCI HAR Dataset/test/X_test.txt', delim_whitespace=True, header=None).values
y_test = pd.read_csv('UCI HAR Dataset/test/y_test.txt', header=None).values.ravel()

# %%
print(X_train_authors.shape)  # Should be (7352, 561)
print(y_train.shape)          # Should be (7352,)
# Out:
# (7352, 561)
# (7352,)

# %%
rf.fit(X_train_authors, y_train)
y_pred_authors_rf = rf.predict(X_test_authors)
print(" ramdom forest acc(author_features):", accuracy_score(y_test, y_pred_authors_rf))
# Out:
#  ramdom forest acc(author_features): 0.9246691550729556
